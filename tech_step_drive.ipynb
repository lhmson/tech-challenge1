# %% [markdown]
# :# **KMS Technology Technical Challenge 1**

# %% [markdown]
# ## 1. Mount to drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/MyDrive/AI-ML/Team_Learn2Win/techchallenge1-sample
# Out:
# /content/drive/MyDrive/AI-ML/Team_Learn2Win/techchallenge1-sample

# %%
ls
# Out:
# assets/  README.md  requirements.txt  Training/  WebApp/

# %% [markdown]
# ## 2. Install requirements python package

# %%
# !pip install -r requirements.txt

# %% [markdown]
# ## 3. Data Preparing

# %% [markdown]
# Generate sample dataset, skip this step if you already have dataset in json format

# %%
import json 

sample_data = {
    'data' : [
          {
              'schema': 'table(name : text, score: number )',
              'question': 'who have score over 9',
              'sql': 'SELECT name FROM TABLE WHERE score > 9'
          }
    ]
}

with open('sample_data.json' , 'w') as f:
  json.dump(sample_data, f)

# %% [markdown]
# ## 4. Turn data into trainable text

# %% [markdown]
# Convert json format in to trainable txt

# %%
cd /content/drive/MyDrive/AI-ML/Team_Learn2Win/techchallenge1-sample/Training
# Out:
# /content/drive/MyDrive/AI-ML/Team_Learn2Win/techchallenge1-sample/Training

# %%
# !python build-dataset.py -i /content/drive/MyDrive/AI-ML/Team_Learn2Win/Dataset/wiki_acadamic.json -o ./train_data.txt

# %%
ls
# Out:
# build-dataset.py  __init__.py     preprocess.py  saved/
# cloud.py          model.py        __pycache__/   train_data.txt
# Example.ipynb     postprocess.py  README.md      train.py

# %% [markdown]
# ## 5. Train model GPT

# %% [markdown]
# Train model with txt dataset

# %%
# !python train.py -i train_data.txt -m 125M -e 3 -o test

# %% [markdown]
# ## 6. Copy model into web app

# %% [markdown]
# Copy model into WebApp/API/server/pretrain-model

# %% [markdown]
# Add your model path in **WebApp/API/server/text2sql/text2sql.py**
#
# model = GPTModel(model_path="./API/server/copy-saved-model-here")

# %% [markdown]
# ## 7. Start Web app

# %%
cd /content/drive/MyDrive/AI-ML/Team_Learn2Win/techchallenge1-sample/WebApp
# Out:
# /content/drive/MyDrive/AI-ML/Team_Learn2Win/techchallenge1-sample/WebApp

# %%
ls
# Out:
# API/  log.txt  ngrok  ngrok-stable-linux-amd64.zip  UI/

# %%
# !pip install pyngrok
# Out:
# ...
#      |████████████████████████████████| 745 kB 5.2 MB/s
# ...
#   Created wheel for pyngrok: filename=pyngrok-5.1.0-py3-none-any.whl size=19007 sha256=0982d6ea0ee670c734f845babf5fa6d14784098fd22f955623ae656f72eb33d9
#   Stored in directory: /root/.cache/pip/wheels/bf/e6/af/ccf6598ecefecd44104069371795cb9b3afbcd16987f6ccfb3
# Successfully built pyngrok
# ...

# %%
# !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# !unzip -qq ngrok-stable-linux-amd64.zip
# Out:
# --2022-05-12 07:36:14--  https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# Resolving bin.equinox.io (bin.equinox.io)... 52.202.168.65, 54.237.133.81, 18.205.222.128, ...
# Connecting to bin.equinox.io (bin.equinox.io)|52.202.168.65|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13832437 (13M) [application/octet-stream]
# Saving to: ‘ngrok-stable-linux-amd64.zip.1’
#
# ngrok-stable-linux- 100%[===================>]  13.19M  35.0MB/s    in 0.4s
#
# 2022-05-12 07:36:15 (35.0 MB/s) - ‘ngrok-stable-linux-amd64.zip.1’ saved [13832437/13832437]
#
# replace ngrok? [y]es, [n]o, [A]ll, [N]one, [r]ename: y

# %% [markdown]
# **Go to https://dashboard.ngrok.com/get-started and get your own token**

# %%
# !ngrok authtoken <the_token>
# Out:
# Authtoken saved to configuration file: /root/.ngrok2/ngrok.yml

# %%
get_ipython().system_raw('./ngrok http 8501 &')

# %% [markdown]
# **Use the output of this command as the link to your Streamlit app (maybe you have to run more than 2 times to get it)**

# %%
# !curl -s http://localhost:4040/api/tunnels | python3 -c \
    "import sys, json; print(json.load(sys.stdin)['tunnels'][0]['public_url'])"

# %%
# !python API/main.py & streamlit run UI/app.py
